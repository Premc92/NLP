# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /home/labsuser/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/labsuser/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/labsuser/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/labsuser/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /home/labsuser/nltk_data...
# ...

# %%
import pandas as pd
import numpy as np

# %%
amazon_data=pd.read_csv('amazon_cells_labelled.txt',delimiter='\t',header=None)
amazon_data.columns=['Sentence','Class']

# %%
amazon_data.head()
# Out:
#                                             Sentence  Class
# 0  So there is no way for me to plug it in here i...      0
# 1                        Good case, Excellent value.      1
# 2                             Great for the jawbone.      1
# 3  Tied to charger for conversations lasting more...      0
# 4                                  The mic is great.      1

# %%
amazon_data['Class'].replace({1:'Pos',0:'Neg'},inplace =True)

# %%
amazon_data['Class'].value_counts()
# Out:
# Neg    500
# Pos    500
# Name: Class, dtype: int64

# %%
amazon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sentence  1000 non-null   object
#  1   Class     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid=SentimentIntensityAnalyzer()

# %%
sid

# %%
text='This is the one of the bad movie in the recent times'

sid.polarity_scores(text)
# Out:
# {'neg': 0.241, 'neu': 0.759, 'pos': 0.0, 'compound': -0.5423}

# %%
print(amazon_data['Sentence'][1],'\n',sid.polarity_scores(amazon_data['Sentence'][1]['pos']))
# Out:
# Good case, Excellent value.
#  {'neg': 0.0, 'neu': 0.1, 'pos': 0.9, 'compound': 0.8402}

# %%
amazon_data['scores']=amazon_data['Sentence'].apply(lambda text:sid.polarity_scores(text))

# %%
amazon_data.head()
# Out:
#                                             Sentence Class  \
# 0  So there is no way for me to plug it in here i...   Neg
# 1                        Good case, Excellent value.   Pos
# 2                             Great for the jawbone.   Pos
# 3  Tied to charger for conversations lasting more...   Neg
# 4                                  The mic is great.   Pos
#
#                                               scores
# 0  {'neg': 0.12, 'neu': 0.88, 'pos': 0.0, 'compou...
# 1  {'neg': 0.0, 'neu': 0.1, 'pos': 0.9, 'compound...
# 2  {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'comp...
# 3  {'neg': 0.287, 'neu': 0.713, 'pos': 0.0, 'comp...
# 4  {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'comp...

# %%
amazon_data['compound']=amazon_data['scores'].apply(lambda score_dict:score_dict['compound'])
amazon_data.head()
# Out:
#                                             Sentence Class  \
# 0  So there is no way for me to plug it in here i...   Neg
# 1                        Good case, Excellent value.   Pos
# 2                             Great for the jawbone.   Pos
# 3  Tied to charger for conversations lasting more...   Neg
# 4                                  The mic is great.   Pos
#
#                                               scores  compound
# 0  {'neg': 0.12, 'neu': 0.88, 'pos': 0.0, 'compou...   -0.3535
# 1  {'neg': 0.0, 'neu': 0.1, 'pos': 0.9, 'compound...    0.8402
# 2  {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'comp...    0.6249
# 3  {'neg': 0.287, 'neu': 0.713, 'pos': 0.0, 'comp...   -0.6145
# 4  {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'comp...    0.6249

# %%
amazon_data['com_score']=amazon_data['compound'].apply(lambda c:'pos' if c>=0 else 'neg')

# %%
amazon_data.head()
# Out:
#                                             Sentence Class  \
# 0  So there is no way for me to plug it in here i...   Neg
# 1                        Good case, Excellent value.   Pos
# 2                             Great for the jawbone.   Pos
# 3  Tied to charger for conversations lasting more...   Neg
# 4                                  The mic is great.   Pos
#
#                                               scores  compound com_score
# 0  {'neg': 0.12, 'neu': 0.88, 'pos': 0.0, 'compou...   -0.3535       neg
# 1  {'neg': 0.0, 'neu': 0.1, 'pos': 0.9, 'compound...    0.8402       pos
# 2  {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'comp...    0.6249       pos
# 3  {'neg': 0.287, 'neu': 0.713, 'pos': 0.0, 'comp...   -0.6145       neg
# 4  {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'comp...    0.6249       pos

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print(accuracy_score(amazon_data['Class'],amazon_data['com_score']))
# Out:
# 0.0
